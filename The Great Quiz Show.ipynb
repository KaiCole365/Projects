# %%
# Intro question
playing = input("Do you want to play? (yes/no) ")

if playing.lower() != "yes":
    quit()

# Welcome message
print("Welcome to the Great Quiz Show!")
user = input("Please enter your name: ")

print("Alright", user, "let's get started!")
score = 0

# Question 1
answer = input("What was the name of the tiger in Winnie the Pooh? \n a. Eeyore \n b. Tigger \n c. Piglet \n d. Roo \n ")
if answer.lower() == "b":
    print("Correct!")
    score += 1
else:
    print("That is incorrect!")
    print("The correct answer was b. Tigger")

# Question 2
answer = input("What is the name of the YouTube famous kids show host with the pink bow? \n a. Mr. Rogers \n b. Ms. Rachel \n c. Ms. Smith \n d. Ms. Sara \n ")
if answer.lower() == "b":
    print("Correct!")
    score += 1
else:
    print("That is incorrect!")
    print("The correct answer was b. Ms. Rachel")

# Question 3
answer = input("What is the chemical symbol for gold? \n a. Ar \n b. Bl \n c. Au \n d. Ag \n ")
if answer.lower() == "c":
    print("Correct!")
    score += 1
else:
    print("That is incorrect!")
    print("The correct answer was c. Au")

# Question 4
answer = input("What is the name of the main villain in the Harry Potter series? \n a. Dolores Umbridge \n b. Severus Snape \n c. Lord Voldemort \n d. Draco Malfoy \n ")
if answer.lower() == "c":
    print("Correct!")
    score += 1
else:
    print("That is incorrect!")
    print("The correct answer was c. Lord Voldemort")

# Question 5
answer = input("How many planets are in the solar system? \n a. 8 \n b. 7 \n c. 10 \n d. 6 \n ")
if answer.lower() == "a":
    print("Correct!")
    score += 1
else:
    print("That is incorrect!")
    print("The correct answer was a. 8")

# Question 6
answer = input("Which country has won the most FIFA World Cup titles? \n a. France \n b. Mexico \n c. Argentina \n d. Brazil \n ")
if answer.lower() == "d":
    print("Correct!")
    score += 1
else:
    print("That is incorrect!")
    print("The correct answer was d. Brazil")

# Question 7
answer = input("What is the fastest land animal? \n a. Jaguar \n b. Panther \n c. Cheetah \n d. Gazelle \n ")
if answer.lower() == "c":
    print("Correct!")
    score += 1
else:
    print("That is incorrect!")
    print("The correct answer was c. Cheetah")

# Question 8
answer = input("How many hearts does an octopus have? \n a. Three \n b. One \n c. Two \n d. Four \n ")
if answer.lower() == "a":
    print("Correct!")
    score += 1
else:
    print("That is incorrect!")
    print("The correct answer was a. Three")

# Question 9
answer = input("In bowling, what is it called when you get three strikes in a row? \n a. A Chicken \n b. A Turkey \n c. A Rooster \n d. A Cow \n ")
if answer.lower() == "b":
    print("Correct!")
    score += 1
else:
    print("That is incorrect!")
    print("The correct answer was b. A Turkey")

# Question 10
answer = input("In which year did the Titanic sink? \n a. 1812 \n b. 1904 \n c. 1892 \n d. 1912 \n ")
if answer.lower() == "d":
    print("Correct!")
    score += 1
else:
    print("That is incorrect!")
    print("The correct answer was d. 1912")

# Qualifying for the bonus question
if score >=8:
  print("Congrats! You've qualified for the bonus question!")

# Bonus question
  answer = input("What is the tallest building in the world? \n a. Big Ben \n b. Eifel Tower \n c. Birj Khalifa \n d. Empire State Building \n ")
  if answer.lower() == "c":
      print("Correct!")
      score += 100
  else:
      print("That is incorrect!")
      print("The correct answer was c. Birj Khalifa")

else:
  pass

print("Great job", user + "!" + " Come back and try for the bonus!")

print(f"You scored {score} today. Nice job", user + "!")
